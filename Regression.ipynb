# %%
import pandas as pd
df = pd.read_csv("C:/Users/likhi/OneDrive/Desktop/CSE 598-SLT/Project/EWTP.csv")
df.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          30.3          21.1    61.741207    87.262192         26.629430
# 1          29.3          20.9    85.943954    97.694801         25.380395
# 2          29.5          22.2    32.008099    69.966370         31.991670
# 3          32.6          21.2    60.070614    91.244827         27.043616
# 4          33.0          27.6    62.508846    86.983963         31.529577
#
#    LDAPS_Tmin_lapse   LDAPS_WS   LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0         23.075077   4.263528  21.399026   0.297776   0.616711  ...
# 1         23.275475   8.697955  53.165713   0.901123   0.867350  ...
# 2         21.475995  10.461500  37.582673   0.012838   0.086090  ...
# 3         23.338373  15.686361  95.842065   0.622580   0.388476  ...
# 4         27.307177   6.493082  49.887497   0.438076   0.458994  ...
#
#    LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0    0.000000    0.000000    0.000479    0.000000  37.5776  126.938   75.0924
# 1    2.642577    0.261794    0.288428    2.315489  37.5507  126.988  132.1180
# 2    0.000000    0.000000    0.000000    0.000000  37.5507  126.937   30.0464
# 3    0.285723    0.335796    0.000000    0.000000  37.6046  127.032   44.7624
# 4    0.000000    0.000000    0.000000    0.000000  37.5102  127.042   54.6384
#
#     Slope  Solar radiation  Next_Tmax
# 0  1.7678      5131.667480       26.4
# 1  0.5931      5918.901367       25.6
# 2  0.8552      5222.419434       30.6
# 3  0.5141      5558.630371       27.2
# 4  0.1457      5635.460449       32.8
#
# [5 rows x 22 columns]

# %%
df.describe(include='all')
# Out:
#        Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# count   7672.000000   7672.000000  7668.000000  7668.000000       7668.000000
# mean      29.765498     23.221363    56.753901    88.370889         29.613750
# std        2.970213      2.413101    14.664511     7.192725          2.948069
# min       20.000000     11.300000    19.794666    58.936283         17.624954
# 25%       27.800000     21.700000    45.962741    84.217754         27.671489
# 50%       29.900000     23.400000    55.032215    89.788502         29.703982
# 75%       32.000000     24.900000    67.181076    93.742725         31.710469
# max       37.600000     29.900000    98.524734   100.000153         38.542255
#
#        LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH    LDAPS_CC1    LDAPS_CC2  \
# count       7668.000000  7668.000000  7668.000000  7668.000000  7668.000000
# mean          23.512166     7.097546    62.528846     0.368696     0.355954
# std            2.346388     2.183788    33.730886     0.262437     0.258035
# min           14.272646     2.882580   -13.603212     0.000000     0.000000
# 25%           22.087282     5.678292    37.291162     0.146631     0.140559
# 50%           23.760100     6.547399    56.888000     0.315508     0.312185
# 75%           25.154219     8.032955    84.235666     0.575501     0.557967
# max           29.619342    21.857621   213.414006     0.967277     0.968353
#
#        ...   LDAPS_PPT1   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  ...  7668.000000  7668.000000  7668.000000  7668.000000  7733.000000
# mean   ...     0.590163     0.483817     0.278519     0.269705    37.544724
# std    ...     1.940501     1.761098     1.162453     1.206890     0.050365
# min    ...     0.000000     0.000000     0.000000     0.000000    37.456200
# 25%    ...     0.000000     0.000000     0.000000     0.000000    37.510200
# 50%    ...     0.000000     0.000000     0.000000     0.000000    37.550700
# 75%    ...     0.052394     0.018260     0.007922     0.000043    37.577600
# max    ...    23.701544    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax
# count  7733.000000  7733.000000  7733.000000      7733.000000  7711.000000
# mean    126.991409    61.871655     1.257197      5341.656783    30.309651
# std       0.079423    54.269245     1.370752       429.379995     3.110451
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      4999.018555    28.300000
# 50%     126.995000    45.716000     0.618000      5437.170410    30.557000
# 75%     127.042000    59.832400     1.767800      5728.624512    32.700000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
# [8 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7733 entries, 0 to 7732
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Present_Tmax      7672 non-null   float64
#  1   Present_Tmin      7672 non-null   float64
#  2   LDAPS_RHmin       7668 non-null   float64
#  3   LDAPS_RHmax       7668 non-null   float64
#  4   LDAPS_Tmax_lapse  7668 non-null   float64
#  5   LDAPS_Tmin_lapse  7668 non-null   float64
#  6   LDAPS_WS          7668 non-null   float64
#  7   LDAPS_LH          7668 non-null   float64
#  8   LDAPS_CC1         7668 non-null   float64
#  9   LDAPS_CC2         7668 non-null   float64
#  10  LDAPS_CC3         7668 non-null   float64
#  11  LDAPS_CC4         7668 non-null   float64
#  12  LDAPS_PPT1        7668 non-null   float64
#  13  LDAPS_PPT2        7668 non-null   float64
#  14  LDAPS_PPT3        7668 non-null   float64
#  15  LDAPS_PPT4        7668 non-null   float64
#  16  lat               7733 non-null   float64
#  17  lon               7733 non-null   float64
#  18  DEM               7733 non-null   float64
#  19  Slope             7733 non-null   float64
#  20  Solar radiation   7733 non-null   float64
#  21  Next_Tmax         7711 non-null   float64
# dtypes: float64(22)
# memory usage: 1.3 MB

# %%
df.isnull().sum()
# Out:
# Present_Tmax        61
# Present_Tmin        61
# LDAPS_RHmin         65
# LDAPS_RHmax         65
# LDAPS_Tmax_lapse    65
# LDAPS_Tmin_lapse    65
# LDAPS_WS            65
# LDAPS_LH            65
# LDAPS_CC1           65
# LDAPS_CC2           65
# LDAPS_CC3           65
# LDAPS_CC4           65
# LDAPS_PPT1          65
# LDAPS_PPT2          65
# LDAPS_PPT3          65
# LDAPS_PPT4          65
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           22
# dtype: int64

# %%
df = df.dropna()

# %%
df.describe(include='all')
# Out:
#        Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# count   7594.000000   7594.000000  7594.000000  7594.000000       7594.000000
# mean      29.748038     23.195654    56.730415    88.359545         29.619535
# std        2.969855      2.405262    14.639427     7.206442          2.947587
# min       20.000000     11.300000    19.794666    58.936283         17.624954
# 25%       27.800000     21.600000    45.961137    84.204340         27.673584
# 50%       29.900000     23.400000    55.023199    89.784122         29.709537
# 75%       32.000000     24.800000    67.118944    93.744694         31.710922
# max       37.600000     29.900000    98.524734   100.000153         38.542255
#
#        LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH    LDAPS_CC1    LDAPS_CC2  \
# count       7594.000000  7594.000000  7594.000000  7594.000000  7594.000000
# mean          23.512125     7.095113    62.512843     0.368601     0.355603
# std            2.345486     2.183467    33.741695     0.262338     0.258016
# min           14.272646     2.882580   -13.603212     0.000000     0.000000
# 25%           22.086951     5.675345    37.211503     0.146551     0.140187
# 50%           23.758577     6.547617    56.905615     0.315917     0.311740
# 75%           25.156160     8.028642    84.276653     0.574550     0.557226
# max           29.619342    21.857621   213.414006     0.967277     0.968353
#
#        ...   LDAPS_PPT1   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  ...  7594.000000  7594.000000  7594.000000  7594.000000  7594.000000
# mean   ...     0.591780     0.483299     0.276878     0.267365    37.544784
# std    ...     1.945029     1.759481     1.159497     1.194118     0.050442
# min    ...     0.000000     0.000000     0.000000     0.000000    37.456200
# 25%    ...     0.000000     0.000000     0.000000     0.000000    37.510200
# 50%    ...     0.000000     0.000000     0.000000     0.000000    37.550700
# 75%    ...     0.053131     0.017824     0.007856     0.000018    37.577600
# max    ...    23.701544    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax
# count  7594.000000  7594.000000  7594.000000      7594.000000  7594.000000
# mean    126.991418    61.914856     1.259757      5343.697613    30.280869
# std       0.079278    54.338359     1.373164       429.854258     3.098722
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      5002.308105    28.300000
# 50%     126.995000    45.716000     0.618000      5441.987305    30.500000
# 75%     127.042000    59.832400     1.767800      5729.485840    32.600000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
# [8 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# dtype: int64

# %%
X = df.drop('Next_Tmax', axis='columns')
y = df['Next_Tmax']

# %%
X.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          30.3          21.1    61.741207    87.262192         26.629430
# 1          29.3          20.9    85.943954    97.694801         25.380395
# 2          29.5          22.2    32.008099    69.966370         31.991670
# 3          32.6          21.2    60.070614    91.244827         27.043616
# 4          33.0          27.6    62.508846    86.983963         31.529577
#
#    LDAPS_Tmin_lapse   LDAPS_WS   LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0         23.075077   4.263528  21.399026   0.297776   0.616711  ...
# 1         23.275475   8.697955  53.165713   0.901123   0.867350  ...
# 2         21.475995  10.461500  37.582673   0.012838   0.086090  ...
# 3         23.338373  15.686361  95.842065   0.622580   0.388476  ...
# 4         27.307177   6.493082  49.887497   0.438076   0.458994  ...
#
#    LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat  \
# 0   0.653336    0.000000    0.000000    0.000479    0.000000  37.5776
# 1   0.895381    2.642577    0.261794    0.288428    2.315489  37.5507
# 2   0.505275    0.000000    0.000000    0.000000    0.000000  37.5507
# 3   0.000000    0.285723    0.335796    0.000000    0.000000  37.6046
# 4   0.313824    0.000000    0.000000    0.000000    0.000000  37.5102
#
#        lon       DEM   Slope  Solar radiation
# 0  126.938   75.0924  1.7678      5131.667480
# 1  126.988  132.1180  0.5931      5918.901367
# 2  126.937   30.0464  0.8552      5222.419434
# 3  127.032   44.7624  0.5141      5558.630371
# 4  127.042   54.6384  0.1457      5635.460449
#
# [5 rows x 21 columns]

# %%
y.head()
# Out:
# 0    26.4
# 1    25.6
# 2    30.6
# 3    27.2
# 4    32.8
# Name: Next_Tmax, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(30,25))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

random_state = 34
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=random_state)

# %%
from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler()

X_train = sc.fit_transform(x_train)
X_test= sc.transform(x_test)

# %%
print(X)
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0             30.3          21.1    61.741207    87.262192         26.629430
# 1             29.3          20.9    85.943954    97.694801         25.380395
# 2             29.5          22.2    32.008099    69.966370         31.991670
# 3             32.6          21.2    60.070614    91.244827         27.043616
# 4             33.0          27.6    62.508846    86.983963         31.529577
# ...            ...           ...          ...          ...               ...
# 7728          29.7          23.1    62.276913    95.811707         28.846006
# 7729          33.1          26.8    43.443817    77.924614         34.647849
# 7730          33.1          25.4    50.856052    92.149277         31.166726
# 7731          32.0          24.1    46.339367    86.733521         31.816415
# 7732          32.0          26.8    63.836815    86.343269         31.520900
#
#       LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            23.075077   4.263528   21.399026   0.297776   0.616711  ...
# 1            23.275475   8.697955   53.165713   0.901123   0.867350  ...
# 2            21.475995  10.461500   37.582673   0.012838   0.086090  ...
# 3            23.338373  15.686361   95.842065   0.622580   0.388476  ...
# 4            27.307177   6.493082   49.887497   0.438076   0.458994  ...
# ...                ...        ...         ...        ...        ...  ...
# 7728         23.819296   5.072551  132.003884   0.238526   0.184225  ...
# 7729         26.702540   5.553541   18.832901   0.173491   0.152533  ...
# 7730         26.287848   5.445318  109.267047   0.170750   0.118597  ...
# 7731         24.781543   6.074005   51.650029   0.342173   0.554225  ...
# 7732         27.514945   6.736187   15.351933   0.484804   0.538203  ...
#
#       LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat  \
# 0      0.653336    0.000000    0.000000    0.000479    0.000000  37.5776
# 1      0.895381    2.642577    0.261794    0.288428    2.315489  37.5507
# 2      0.505275    0.000000    0.000000    0.000000    0.000000  37.5507
# 3      0.000000    0.285723    0.335796    0.000000    0.000000  37.6046
# 4      0.313824    0.000000    0.000000    0.000000    0.000000  37.5102
# ...         ...         ...         ...         ...         ...      ...
# 7728   0.011823    0.000000    0.000000    0.000000    0.000000  37.5776
# 7729   0.050287    0.000000    0.000000    0.000000    0.000000  37.5237
# 7730   0.029190    0.000000    0.000000    0.000000    0.000000  37.5507
# 7731   0.143324    0.000000    0.000497    0.000000    0.000000  37.5372
# 7732   0.339272    0.000000    0.000000    0.000000    0.000000  37.5507
#
#           lon       DEM   Slope  Solar radiation
# 0     126.938   75.0924  1.7678      5131.667480
# 1     126.988  132.1180  0.5931      5918.901367
# 2     126.937   30.0464  0.8552      5222.419434
# 3     127.032   44.7624  0.5141      5558.630371
# 4     127.042   54.6384  0.1457      5635.460449
# ...       ...       ...     ...              ...
# 7728  126.838   12.3700  0.0985      5537.372070
# 7729  126.970   19.5844  0.2713      5288.856445
# 7730  127.135   35.0380  0.5055      5055.825195
# 7731  127.085   28.7000  0.6233      5190.547852
# 7732  126.937   30.0464  0.8552      5632.461914
#
# [7594 rows x 21 columns]

# %%
import numpy as np
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, explained_variance_score, median_absolute_error, max_error, mean_squared_log_error
param_kernel=['linear', 'rbf', 'poly', 'sigmoid']

for ker in param_kernel:
    print('\nFor the %s kernel \n'%(ker))
    svr = SVR(kernel=ker)
    svr.fit(X_train,y_train)

    Y_pred = svr.predict(X_test)
    #print(Y_pred)

    mae = mean_absolute_error(y_test, Y_pred)
    mse = mean_squared_error(y_test, Y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, Y_pred)
    ev = explained_variance_score(y_test, Y_pred)
    medae = median_absolute_error(y_test, Y_pred)
    me = max_error(y_test, Y_pred)
    #msle = mean_squared_log_error(y_test, Y_pred)

    print('MAE: {:.2f}'.format(mae))
    print('MSE: {:.2f}'.format(mse))
    print('RMSE: {:.2f}'.format(rmse))
    print('R2 score: {:.2f}'.format(r2))
    print('EV score: {:.2f}'.format(ev))
    print('MedAE: {:.2f}'.format(medae))
    print('MaxError: {:.2f}'.format(me))
    #print('MSLE: {:.2f}'.format(msle))
# Out:
# For the linear kernel
#
# MAE: 1.01
# MSE: 1.85
# RMSE: 1.36
# R2 score: 0.80
# EV score: 0.80
# MedAE: 0.75
# MaxError: 6.49
#
# For the rbf kernel
#
# MAE: 0.88
# MSE: 1.46
# RMSE: 1.21
# R2 score: 0.85
# EV score: 0.85
# MedAE: 0.66
# MaxError: 9.40
#
# For the poly kernel
#
# MAE: 0.92
# MSE: 1.53
# RMSE: 1.24
# R2 score: 0.84
# EV score: 0.84
# MedAE: 0.71
# MaxError: 9.93
#
# For the sigmoid kernel
#
# MAE: 28.95
# MSE: 1543.29
# RMSE: 39.28
# R2 score: -162.64
# EV score: -155.37
# MedAE: 22.65
# MaxError: 222.69

# %%
import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, RegressorMixin
from numpy import exp,dot
from scipy.spatial.distance import cdist

class LSSVMRegression(BaseEstimator, RegressorMixin):
    """
    An Least Squared Support Vector Machine (LS-SVM) regression class, build
    on the BaseEstimator and RegressorMixin base classes of sklearn.

    Attributes:
        - gamma : the hyper-parameter (float)
        - kernel: the kernel used     (string)
        - kernel_: the actual kernel function
        - x : the data on which the LSSVM is trained (call it support vectors)
        - y : the targets for the training data
        - coef_ : coefficents of the support vectors
        - intercept_ : intercept term

    """
    def __init__(self, gamma: float = 1.0, kernel: str = None, c: float = 1.0,
                 d: float = 2, sigma: float = 1.0):
        self.gamma = gamma
        self.c = c
        self.d = d
        self.sigma = sigma
        if kernel is None:
            self.kernel = 'rbf'
        else:
            self.kernel = kernel

        params = dict()
        if kernel == 'poly':
            params['c'] = c
            params['d'] = d
        elif kernel == 'rbf':
            params['sigma'] = sigma

        self.kernel_ = LSSVMRegression.__set_kernel(self.kernel, **params)

        #model parameters
        self.x = None
        self.y = None
        self.coef_ = None
        self.intercept_ = None

    def get_params(self, deep=True):
        return {"c": self.c, "d": self.d, "gamma": self.gamma,
                "kernel": self.kernel, "sigma":self.sigma}

    def set_params(self, **parameters):
        #print("SETTING PARAMETERS IN LSSVM:",parameters.items())

        for parameter, value in parameters.items():
            #setattr should do the trick for gamma,c,d,sigma and kernel
            setattr(self, parameter, value)
        #now also update the actual kernel
        params = dict()
        if self.kernel == 'poly':
            params['c'] = self.c
            params['d'] = self.d
        elif self.kernel == 'rbf':
            params['sigma'] = self.sigma
        self.kernel_ = LSSVMRegression.__set_kernel(self.kernel, **params)

        return self

    def set_attributes(self, **parameters):
        #not the most efficient way of doing it...but sufficient for the time being
        for param, value in parameters.items():
            if param == 'intercept_':
                self.intercept_ = value
            elif param == 'coef_':
                self.coef_ = value
            elif param == 'support_':
                self.x = value

    @staticmethod
    def __set_kernel(name: str, **params):
        def linear(xi, xj):
            return np.dot(xi, xj.T)

        def poly(xi, xj, c=params.get('c', 1.0), d=params.get('d', 2)):
            return ((np.dot(xi, xj.T))/c  + 1)**d

        def rbf(xi, xj, sigma=params.get('sigma', 1.0)):

            if (xi.ndim == 2 and xi.ndim == xj.ndim): # both are 2D matrices
                return np.exp(-(cdist(xi, xj, metric='sqeuclidean'))/(2*(sigma**2)))
            elif ((xi.ndim < 2) and (xj.ndim < 3)):
                ax = len(xj.shape)-1 #compensate for python zero-base
                return np.exp(-(np.dot(xi, xi) + (xj**2).sum(axis=ax)
                                - 2*np.dot(xi, xj.T))/(2*(sigma**2)))
            else:
                message = "The rbf kernel is not suited for arrays with rank >2"
                raise Exception(message)

        def sigmoid(xi, xj, gamma=params.get('gamma', 1.0)):
            return np.tanh(gamma * np.dot(xi, xj.T))

        kernels = {'linear': linear, 'poly': poly, 'rbf': rbf, 'sigmoid': sigmoid}

        if kernels.get(name) is not None:
            return kernels[name]
        else: #unknown kernel: crash and burn?
            message = "Kernel "+name+" is not implemented. Please choose from : "
            message += str(list(kernels.keys())).strip('[]')
            raise KeyError(message)

    def __OptimizeParams(self):
        #eq 3.6: Omega_kl = y_ky_lK(x_k,x_l)
        # !! note that the product of a vector and the transposed is a dot-product
        #    and we need an outer product
        #For classification and Regression, the matrices are slightly different...
        # (why? except for what came out of solving equations?
        # Dilmen et al, IFAC PapersOnline 50(1), 8642-8647 (2017))

        # Classification
        # Omega = np.multiply( np.multiply.outer(y,y), self.kernel_(X,X) ) # correct version
        #A_dag = np.linalg.pinv(np.block([
        #    [0,                           y.T                   ],
        #    [y,   Omega + self.gamma**-1 * np.eye(len(y_values))]
        #])) #need to check if the matrix is OK--> y.T parts
        #B = np.array([0]+[1]*len(y_values))

        #Regression
        Omega = self.kernel_(self.x, self.x)
        Ones = np.array([[1]]*len(self.y)) # needs to be a 2D 1-column vector, hence [[ ]]

        A_dag = np.linalg.pinv(np.block([
            [0,                           Ones.T                      ],
            [Ones,   Omega + self.gamma**-1 * np.identity(len(self.y))]
        ])) #need to check if the matrix is OK--> y.T parts
        B = np.concatenate((np.array([0]), self.y), axis=None)

        solution = np.dot(A_dag, B)
        self.intercept_ = solution[0]
        self.coef_      = solution[1:]


    def fit(self, X: np.ndarray, y: np.ndarray):
        #print("IN FIT==> GAMMA=",self.gamma,"  SIGMA=",self.sigma)

        if isinstance(X, (pd.DataFrame, pd.Series)): #checks if X is an instance of either types
            Xloc = X.to_numpy()
        else:
            Xloc = X

        if isinstance(y, (pd.DataFrame, pd.Series)):
            yloc = y.to_numpy()
        else:
            yloc = y

        #check the dimensionality of the input
        if (Xloc.ndim == 2) and (yloc.ndim == 1):
            self.x = Xloc
            self.y = yloc
            self.__OptimizeParams()
        else:
            message = "The fit procedure requires a 2D numpy array of features "\
                "and 1D array of targets"
            raise Exception(message)

    def predict(self, X: np.ndarray)->np.ndarray:
        Ker = self.kernel_(X, self.x) #second component should be the array of training vectors
        Y = np.dot(self.coef_, Ker.T) + self.intercept_
        return Y

# %%
for ker in param_kernel:
    print('\nFor the %s kernel \n'%(ker))
    lssvr = LSSVMRegression(kernel=ker)
    lssvr.fit(X_train,y_train)

    Y_pred = lssvr.predict(X_test)
    #print(Y_pred)

    mae = mean_absolute_error(y_test, Y_pred)
    mse = mean_squared_error(y_test, Y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, Y_pred)
    ev = explained_variance_score(y_test, Y_pred)
    medae = median_absolute_error(y_test, Y_pred)
    me = max_error(y_test, Y_pred)
    #msle = mean_squared_log_error(y_test, Y_pred)

    print('MAE: {:.2f}'.format(mae))
    print('MSE: {:.2f}'.format(mse))
    print('RMSE: {:.2f}'.format(rmse))
    print('R2 score: {:.2f}'.format(r2))
    print('EV score: {:.2f}'.format(ev))
    print('MedAE: {:.2f}'.format(medae))
    print('MaxError: {:.2f}'.format(me))
    #print('MaxError: {:.2f}'.format(msle))
# Out:
# For the linear kernel
#
# MAE: 1.01
# MSE: 1.84
# RMSE: 1.36
# R2 score: 0.81
# EV score: 0.81
# MedAE: 0.78
# MaxError: 6.52
#
# For the rbf kernel
#
# MAE: 0.89
# MSE: 1.40
# RMSE: 1.18
# R2 score: 0.85
# EV score: 0.85
# MedAE: 0.70
# MaxError: 9.33
#
# For the poly kernel
#
# MAE: 0.90
# MSE: 1.39
# RMSE: 1.18
# R2 score: 0.85
# EV score: 0.85
# MedAE: 0.71
# MaxError: 5.43
#
# For the sigmoid kernel
#
# MAE: 20.10
# MSE: 1036.95
# RMSE: 32.20
# R2 score: -108.95
# EV score: -108.93
# MedAE: 14.51
# MaxError: 460.00
